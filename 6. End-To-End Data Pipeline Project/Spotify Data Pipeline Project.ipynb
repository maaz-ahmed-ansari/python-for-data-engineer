# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.24.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.0.8-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: requests>=2.25.0 in c:\users\maaza\appdata\local\programs\python\python310\lib\site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\maaza\appdata\local\programs\python\python310\lib\site-packages (from spotipy) (2.1.0)
# Collecting async-timeout>=4.0.3 (from redis>=3.5.3->spotipy)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\maaza\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maaza\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.25.0->spotipy) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maaza\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.25.0->spotipy) (2023.11.17)
# Downloading spotipy-2.24.0-py3-none-any.whl (30 kB)
# Downloading redis-5.0.8-py3-none-any.whl (255 kB)
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Installing collected packages: async-timeout, redis, spotipy
# Successfully installed async-timeout-4.0.3 redis-5.0.8 spotipy-2.24.0

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="", client_secret="")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"
playlist_link1 = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f&nd=1&dlsi=1d27bc4546264270"

# %%
playlist_URI = playlist_link1.split("/")[-1].split('?')[0]
playlist_URI
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'type': 'album',
#  'album_type': 'single',
#  'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N',
#  'id': '10FLjwfpbxLmW8c25Xyc2N',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45',
#    'width': 64}],
#  'name': 'Die With A Smile',
#  'release_date': '2024-08-16',
#  'release_date_precision': 'day',
#  'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#    'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#    'id': '1HY2Jd0NmPuamShAr6KMms',
#    'name': 'Lady Gaga',
#    'type': 'artist',
#    'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#    'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#    'id': '0du5cEVh5yTK9QJze8zA0C',
#    'name': 'Bruno Mars',
#    'type': 'artist',
#    'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  'total_tracks': 1}

# %%
data['items'][0]['track']['album']['id']
# Out:
# '10FLjwfpbxLmW8c25Xyc2N'

# %%
data['items'][0]['track']['album']['id']
# Out:
# '10FLjwfpbxLmW8c25Xyc2N'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Die With A Smile'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-08-16'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['artists'][0]['name']
# Out:
# 'Lady Gaga'

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'name': 'Die With A Smile',
#   'release_date': '2024-08-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '5bBaoign62r1i7OV8w7mi9',
#   'name': 'Please Please Please',
#   'release_date': '2024-06-06',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/5bBaoign62r1i7OV8w7mi9'},
#  {'album_id': '5quMTd5zeI9yW5UDua8wS4',
#   'name': 'Espresso',
#   'release_date': '2024-04-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'},
#  {'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'name': 'MUSE',
#   'release_date': '2024-07-19',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '5ylbxH7EqpsmHZCRuiYewS',
#   'name': 'Si Antes Te Hubiera Conocido',
#   'release_date': '2024-06-21',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5ylbxH7EqpsmHZCRuiYewS'},
#  {'album_id': '1WAjjRMfZjEXtB0lQrAw6Q',
#   'name': 'Good Luck, Babe!',
#   'release_date': '2024-04-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1WAjjRMfZjEXtB0lQrAw6Q'},
#  {'album_id': '168CdR21lfn0TTyw1Pkdcm',
#   'name': 'Fireworks & Rollerblades',
#   'release_date': '2024-04-05',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/168CdR21lfn0TTyw1Pkdcm'},
#  {'album_id': '6Yw4204wbgmpsGTzjXBhYD',
#   'name': 'Big Dawgs',
#   'release_date': '2024-07-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6Yw4204wbgmpsGTzjXBhYD'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '20RMokVwJ2wjQ0s8FOdOFC',
#   'name': 'No Strings Attached',
#   'release_date': '2000-03-21',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/20RMokVwJ2wjQ0s8FOdOFC'},
#  {'album_id': '3rQE6GuZuvLF82h0o3Xqqd',
#   'name': 'Guess featuring Billie Eilish',
#   'release_date': '2024-08-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3rQE6GuZuvLF82h0o3Xqqd'},
#  {'album_id': '0DLvFVIfwt3OHdK9kGeEM3',
#   'name': "Where I've Been, Isn't Where I'm Going",
#   'release_date': '2024-05-31',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/0DLvFVIfwt3OHdK9kGeEM3'},
#  {'album_id': '3P4SQqMMgjqfqVxgLwtYRk',
#   'name': 'Unreal Unearth: Unheard',
#   'release_date': '2024-03-22',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/3P4SQqMMgjqfqVxgLwtYRk'},
#  {'album_id': '6MikZBKCtKfPM4439yzBRz',
#   'name': 'EL COMIENZO',
#   'release_date': '2024-08-09',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/6MikZBKCtKfPM4439yzBRz'},
#  {'album_id': '7nacKlk586eLRBSIsrk9DB',
#   'name': "I've Tried Everything But Therapy (Part 1)",
#   'release_date': '2023-09-15',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7nacKlk586eLRBSIsrk9DB'},
#  {'album_id': '2ha4ucrONN0cihLMkP02Ch',
#   'name': 'New Woman (feat. ROSALÍA)',
#   'release_date': '2024-08-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2ha4ucrONN0cihLMkP02Ch'},
#  {'album_id': '4BbsHmXEghoPPevQjPnHXx',
#   'name': 'F-1 Trillion',
#   'release_date': '2024-08-15',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/4BbsHmXEghoPPevQjPnHXx'},
#  {'album_id': '5JjnoGJyOxfSZUZtk2rRwZ',
#   'name': 'Not Like Us',
#   'release_date': '2024-05-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ'},
#  {'album_id': '2Z1gnUf3nbn6DtwZSUIH54',
#   'name': 'MILLION DOLLAR BABY',
#   'release_date': '2024-04-26',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/2Z1gnUf3nbn6DtwZSUIH54'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '2m0euKZUDcoyEXHIS5MFCq',
#   'name': 'Alibi (with Pabllo Vittar & Yseult)',
#   'release_date': '2024-06-28',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2m0euKZUDcoyEXHIS5MFCq'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '4M8ThNHbNjda2cPwL8XZHS',
#   'name': 'Move',
#   'release_date': '2024-06-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4M8ThNHbNjda2cPwL8XZHS'},
#  {'album_id': '4JDXBZdRPId4devseaAOKH',
#   'name': 'DECIDE',
#   'release_date': '2022-09-16',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/4JDXBZdRPId4devseaAOKH'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '5EYKrEDnKhhcNxGedaRQeK',
#   'name': 'eternal sunshine',
#   'release_date': '2024-03-08',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/5EYKrEDnKhhcNxGedaRQeK'},
#  {'album_id': '0EiI8ylL0FmWWpgHVTsZjZ',
#   'name': 'The Rise and Fall of a Midwest Princess',
#   'release_date': '2023-09-22',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/0EiI8ylL0FmWWpgHVTsZjZ'},
#  {'album_id': '4sD1qg4jwTZR4mvR4Iflk5',
#   'name': 'Strange Trails',
#   'release_date': '2015-04-06',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/4sD1qg4jwTZR4mvR4Iflk5'},
#  {'album_id': '7tzVd1fwkxsorytCBjEJkU',
#   'name': 'The Idol Episode 4 (Music from the HBO Original Series)',
#   'release_date': '2023-06-23',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/7tzVd1fwkxsorytCBjEJkU'},
#  {'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'name': 'Lover',
#   'release_date': '2019-08-23',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#  {'album_id': '4xkM0BwLM9H2IUcbYzpcBI',
#   'name': 'I Love You.',
#   'release_date': '2013-04-19',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/4xkM0BwLM9H2IUcbYzpcBI'},
#  {'album_id': '3VNxRarx9HUI5w7DHv0TBj',
#   'name': 'Stargazing',
#   'release_date': '2024-05-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3VNxRarx9HUI5w7DHv0TBj'},
#  {'album_id': '78bpIziExqiI9qztvNFlQu',
#   'name': 'AM',
#   'release_date': '2013-09-09',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/78bpIziExqiI9qztvNFlQu'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '40HsqPqeSR9Xe3IyAJWr6e',
#   'name': 'What Happens Now?',
#   'release_date': '2024-02-16',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/40HsqPqeSR9Xe3IyAJWr6e'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '0lgs2Sa82lyX89nBUWyUy6',
#   'name': 'FERXXOCALIPSIS',
#   'release_date': '2023-12-01',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/0lgs2Sa82lyX89nBUWyUy6'},
#  {'album_id': '2lIZef4lzdvZkiiCzvPKj7',
#   'name': 'BRAT',
#   'release_date': '2024-06-07',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/2lIZef4lzdvZkiiCzvPKj7'},
#  {'album_id': '5H7sO778w4hgr2v2600ajN',
#   'name': 'UWAIE',
#   'release_date': '2024-08-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5H7sO778w4hgr2v2600ajN'},
#  {'album_id': '3IdVqIfyLPqxPZusYgifLo',
#   'name': 'Ohnana',
#   'release_date': '2024-06-06',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3IdVqIfyLPqxPZusYgifLo'},
#  {'album_id': '1CEODgTmTwLyabvwd7HBty',
#   'name': 'Viva La Vida or Death and All His Friends',
#   'release_date': '2008-05-26',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/1CEODgTmTwLyabvwd7HBty'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '5nzSCZ7NhKvAysI0tmNOdD',
#   'name': 'yustyna',
#   'release_date': '2024-07-11',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/5nzSCZ7NhKvAysI0tmNOdD'},
#  {'album_id': '18NOKLkZETa4sWwLMIm0UZ',
#   'name': 'UTOPIA',
#   'release_date': '2023-07-28',
#   'total_tracks': 19,
#   'url': 'https://open.spotify.com/album/18NOKLkZETa4sWwLMIm0UZ'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '63IolVUykZCHMlu2zu9jHS',
#   'name': 'THE FIRST TIME',
#   'release_date': '2023-11-10',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/63IolVUykZCHMlu2zu9jHS'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'}]

# %%
data['items'][0]
# Out:
# {'added_at': '2024-08-30T09:42:25Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'type': 'album',
#    'album_type': 'single',
#    'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N',
#    'id': '10FLjwfpbxLmW8c25Xyc2N',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45',
#      'width': 64}],
#    'name': 'Die With A Smile',
#    'release_date': '2024-08-16',
#    'release_date_precision': 'day',
#    'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#      'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#      'id': '0du5cEVh5yTK9QJze8zA0C',
#      'name': 'Bruno Mars',
#      'type': 'artist',
#      'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#    'total_tracks': 1},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#     'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#     'id': '0du5cEVh5yTK9QJze8zA0C',
#     'name': 'Bruno Mars',
#     'type': 'artist',
#     'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#   'disc_number': 1,
#   'track_number': 1,
#   'duration_ms': 251667,
#   'external_ids': {'isrc': 'USUM72409273'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe'},
#   'href': 'https://api.spotify.com/v1/tracks/2plbrEY59IikOBgBGLjaoe',
#   'id': '2plbrEY59IikOBgBGLjaoe',
#   'name': 'Die With A Smile',
#   'popularity': 96,
#   'uri': 'spotify:track:2plbrEY59IikOBgBGLjaoe',
#   'is_local': False},
#  'video_thumbnail': {'url': None}}

# %%
artist_list = []
for row in data['items']:
    for artist in row['track']['artists']:
        artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_urls':artist['href']}
        artist_list.append(artist_dict)

# %%
# artist_list = []
# for row in data['items']:
#     for key, value in row.items():
#         if key == "track":
#             for artist in value['artists']:
#                 artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
#                 artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_urls': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_urls': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_urls': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_urls': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_urls': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '1oSPZhvZMIrWW5I41kPkkY',
#   'artist_name': 'Jimin',
#   'external_urls': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_urls': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'external_urls': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'artist_name': 'Chappell Roan',
#   'external_urls': 'https://api.spotify.com/v1/artists/7GlBOeep6PqTfFi59PTUUN'},
#  {'artist_id': '22wbnEMDvgVIAGdFeek6ET',
#   'artist_name': 'Benson Boone',
#   'external_urls': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET'},
#  {'artist_id': '4nVa6XlBFlIkF6msW57PHp',
#   'artist_name': 'Hanumankind',
#   'external_urls': 'https://api.spotify.com/v1/artists/4nVa6XlBFlIkF6msW57PHp'},
#  {'artist_id': '6tYCSHLtTI54AQJFOMfU45',
#   'artist_name': 'Kalmi',
#   'external_urls': 'https://api.spotify.com/v1/artists/6tYCSHLtTI54AQJFOMfU45'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_urls': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_urls': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '6Ff53KvcvAj5U7Z1vojB5o',
#   'artist_name': '*NSYNC',
#   'external_urls': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o'},
#  {'artist_id': '25uiPmTg16RbhZWAqwLBy5',
#   'artist_name': 'Charli xcx',
#   'external_urls': 'https://api.spotify.com/v1/artists/25uiPmTg16RbhZWAqwLBy5'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_urls': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '3y2cIKLjiOlp1Np37WiUdH',
#   'artist_name': 'Shaboozey',
#   'external_urls': 'https://api.spotify.com/v1/artists/3y2cIKLjiOlp1Np37WiUdH'},
#  {'artist_id': '2FXC3k01G6Gw61bmprjgqS',
#   'artist_name': 'Hozier',
#   'external_urls': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS'},
#  {'artist_id': '7CvTknweLr9feJtRGrpDBy',
#   'artist_name': 'FloyyMenor',
#   'external_urls': 'https://api.spotify.com/v1/artists/7CvTknweLr9feJtRGrpDBy'},
#  {'artist_id': '1Yj5Xey7kTwvZla8sqdsdE',
#   'artist_name': 'Cris Mj',
#   'external_urls': 'https://api.spotify.com/v1/artists/1Yj5Xey7kTwvZla8sqdsdE'},
#  {'artist_id': '33qOK5uJ8AR2xuQQAhHump',
#   'artist_name': 'Teddy Swims',
#   'external_urls': 'https://api.spotify.com/v1/artists/33qOK5uJ8AR2xuQQAhHump'},
#  {'artist_id': '5L1lO4eRHmJ7a0Q6csE5cT',
#   'artist_name': 'LISA',
#   'external_urls': 'https://api.spotify.com/v1/artists/5L1lO4eRHmJ7a0Q6csE5cT'},
#  {'artist_id': '7ltDVBr6mKbRvohxheJ9h1',
#   'artist_name': 'ROSALÍA',
#   'external_urls': 'https://api.spotify.com/v1/artists/7ltDVBr6mKbRvohxheJ9h1'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'external_urls': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_urls': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_urls': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '1WaFQSHVGZQJTbf0BdxdNo',
#   'artist_name': 'Tommy Richman',
#   'external_urls': 'https://api.spotify.com/v1/artists/1WaFQSHVGZQJTbf0BdxdNo'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_urls': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '5MraexJKZDrQYzS98kNwie',
#   'artist_name': 'Sevdaliza',
#   'external_urls': 'https://api.spotify.com/v1/artists/5MraexJKZDrQYzS98kNwie'},
#  {'artist_id': '6tzRZ39aZlNqlUzQlkuhDV',
#   'artist_name': 'Pabllo Vittar',
#   'external_urls': 'https://api.spotify.com/v1/artists/6tzRZ39aZlNqlUzQlkuhDV'},
#  {'artist_id': '1QsdzIKkTT5gDFj8GB1cIX',
#   'artist_name': 'Yseult',
#   'external_urls': 'https://api.spotify.com/v1/artists/1QsdzIKkTT5gDFj8GB1cIX'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_urls': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '2loEsOijJ6XiGzWYFXMIRk',
#   'artist_name': 'Adam Port',
#   'external_urls': 'https://api.spotify.com/v1/artists/2loEsOijJ6XiGzWYFXMIRk'},
#  {'artist_id': '6XjgqvaVLUib6lCerbZrYD',
#   'artist_name': 'Stryv',
#   'external_urls': 'https://api.spotify.com/v1/artists/6XjgqvaVLUib6lCerbZrYD'},
#  {'artist_id': '26WKgv73kRHD0gEDKD1i8j',
#   'artist_name': 'Keinemusik',
#   'external_urls': 'https://api.spotify.com/v1/artists/26WKgv73kRHD0gEDKD1i8j'},
#  {'artist_id': '2yyaNPcdxZcn4iutCcLMaC',
#   'artist_name': 'Orso',
#   'external_urls': 'https://api.spotify.com/v1/artists/2yyaNPcdxZcn4iutCcLMaC'},
#  {'artist_id': '37lTKHi901VnwngQ7C8noT',
#   'artist_name': 'Malachiii',
#   'external_urls': 'https://api.spotify.com/v1/artists/37lTKHi901VnwngQ7C8noT'},
#  {'artist_id': '5p9HO3XC5P3BLxJs5Mtrhm',
#   'artist_name': 'Djo',
#   'external_urls': 'https://api.spotify.com/v1/artists/5p9HO3XC5P3BLxJs5Mtrhm'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_urls': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'artist_name': 'Ariana Grande',
#   'external_urls': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'artist_name': 'Chappell Roan',
#   'external_urls': 'https://api.spotify.com/v1/artists/7GlBOeep6PqTfFi59PTUUN'},
#  {'artist_id': '6ltzsmQQbmdoHHbLZ4ZN25',
#   'artist_name': 'Lord Huron',
#   'external_urls': 'https://api.spotify.com/v1/artists/6ltzsmQQbmdoHHbLZ4ZN25'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_urls': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '250b0Wlc5Vk0CoUsaCY84M',
#   'artist_name': 'JENNIE',
#   'external_urls': 'https://api.spotify.com/v1/artists/250b0Wlc5Vk0CoUsaCY84M'},
#  {'artist_id': '1pBLC0qVRTB5zVMuteQ9jJ',
#   'artist_name': 'Lily-Rose Depp',
#   'external_urls': 'https://api.spotify.com/v1/artists/1pBLC0qVRTB5zVMuteQ9jJ'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_urls': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '77SW9BnxLY8rJ0RciFqkHh',
#   'artist_name': 'The Neighbourhood',
#   'external_urls': 'https://api.spotify.com/v1/artists/77SW9BnxLY8rJ0RciFqkHh'},
#  {'artist_id': '3bO19AOone0ubCsfDXDtYt',
#   'artist_name': 'Myles Smith',
#   'external_urls': 'https://api.spotify.com/v1/artists/3bO19AOone0ubCsfDXDtYt'},
#  {'artist_id': '7Ln80lUS6He07XvHI8qqHH',
#   'artist_name': 'Arctic Monkeys',
#   'external_urls': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_urls': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '7Ez6lTtSMjMf2YSYpukP1I',
#   'artist_name': 'Dasha',
#   'external_urls': 'https://api.spotify.com/v1/artists/7Ez6lTtSMjMf2YSYpukP1I'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_urls': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '2LRoIwlKmHjgvigdNGBHNo',
#   'artist_name': 'Feid',
#   'external_urls': 'https://api.spotify.com/v1/artists/2LRoIwlKmHjgvigdNGBHNo'},
#  {'artist_id': '7jAs1uPnpfNmT6e5qtEPxq',
#   'artist_name': 'ATL Jacob',
#   'external_urls': 'https://api.spotify.com/v1/artists/7jAs1uPnpfNmT6e5qtEPxq'},
#  {'artist_id': '25uiPmTg16RbhZWAqwLBy5',
#   'artist_name': 'Charli xcx',
#   'external_urls': 'https://api.spotify.com/v1/artists/25uiPmTg16RbhZWAqwLBy5'},
#  {'artist_id': '3UTF2no3muGdiFXVujl94i',
#   'artist_name': 'Kapo',
#   'external_urls': 'https://api.spotify.com/v1/artists/3UTF2no3muGdiFXVujl94i'},
#  {'artist_id': '3UTF2no3muGdiFXVujl94i',
#   'artist_name': 'Kapo',
#   'external_urls': 'https://api.spotify.com/v1/artists/3UTF2no3muGdiFXVujl94i'},
#  {'artist_id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'artist_name': 'Coldplay',
#   'external_urls': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_urls': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '0PCCGZ0wGLizHt2KZ7hhA2',
#   'artist_name': 'Artemas',
#   'external_urls': 'https://api.spotify.com/v1/artists/0PCCGZ0wGLizHt2KZ7hhA2'},
#  {'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'artist_name': 'Travis Scott',
#   'external_urls': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'external_urls': 'https://api.spotify.com/v1/artists/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_urls': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '2tIP7SsRs7vjIcLrU85W8J',
#   'artist_name': 'The Kid LAROI',
#   'external_urls': 'https://api.spotify.com/v1/artists/2tIP7SsRs7vjIcLrU85W8J'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_urls': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                  name release_date  total_tracks  \
# 0  10FLjwfpbxLmW8c25Xyc2N      Die With A Smile   2024-08-16             1
# 1  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT   2024-05-17            10
# 2  5bBaoign62r1i7OV8w7mi9  Please Please Please   2024-06-06             2
# 3  5quMTd5zeI9yW5UDua8wS4              Espresso   2024-04-12             1
# 4  15XcLhiVMlSOipUddTNDnr                  MUSE   2024-07-19             7
#
#                                                  url
# 0  https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 1  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 2  https://open.spotify.com/album/5bBaoign62r1i7O...
# 3  https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 4  https://open.spotify.com/album/15XcLhiVMlSOipU...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id        artist_name  \
# 0  1HY2Jd0NmPuamShAr6KMms          Lady Gaga
# 1  0du5cEVh5yTK9QJze8zA0C         Bruno Mars
# 2  6qqNVTkY8uBg9cP3Jd7DAH      Billie Eilish
# 3  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
# 4  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
#
#                                        external_urls
# 0  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 1  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 2  https://api.spotify.com/v1/artists/6qqNVTkY8uB...
# 3  https://api.spotify.com/v1/artists/74KM79TiuVK...
# 4  https://api.spotify.com/v1/artists/74KM79TiuVK...

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id             song_name  duration_ms  \
# 0  2plbrEY59IikOBgBGLjaoe      Die With A Smile       251667
# 1  6dOtVTDdiauQNBQEDOtlAB    BIRDS OF A FEATHER       210373
# 2  5N3hjp1WNayUPZrA8kJmJP  Please Please Please       186365
# 3  2qSkIjg1o9h3YT9RAgYN75              Espresso       175459
# 4  7tI8dRuH2Yc6RuoTjxo4dU                   Who       170887
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/2plbrEY59IikOBg...          96
# 1  https://open.spotify.com/track/6dOtVTDdiauQNBQ...         100
# 2  https://open.spotify.com/track/5N3hjp1WNayUPZr...          97
# 3  https://open.spotify.com/track/2qSkIjg1o9h3YT9...          97
# 4  https://open.spotify.com/track/7tI8dRuH2Yc6Ruo...          94
#
#              song_added                album_id               artist_id
# 0  2024-08-30T09:42:25Z  10FLjwfpbxLmW8c25Xyc2N  1HY2Jd0NmPuamShAr6KMms
# 1  2024-08-30T09:42:25Z  7aJuG4TFXa2hmE4z1yxc3n  6qqNVTkY8uBg9cP3Jd7DAH
# 2  2024-08-30T09:42:25Z  5bBaoign62r1i7OV8w7mi9  74KM79TiuVKeVCqs8QtB0B
# 3  2024-08-30T09:42:25Z  5quMTd5zeI9yW5UDua8wS4  74KM79TiuVKeVCqs8QtB0B
# 4  2024-08-30T09:42:25Z  15XcLhiVMlSOipUddTNDnr  1oSPZhvZMIrWW5I41kPkkY

# %%
artist_df.head()
# Out:
#                 artist_id        artist_name  \
# 0  1HY2Jd0NmPuamShAr6KMms          Lady Gaga
# 1  0du5cEVh5yTK9QJze8zA0C         Bruno Mars
# 2  6qqNVTkY8uBg9cP3Jd7DAH      Billie Eilish
# 3  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
# 5  1oSPZhvZMIrWW5I41kPkkY              Jimin
#
#                                        external_urls
# 0  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 1  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 2  https://api.spotify.com/v1/artists/6qqNVTkY8uB...
# 3  https://api.spotify.com/v1/artists/74KM79TiuVK...
# 5  https://api.spotify.com/v1/artists/1oSPZhvZMIr...

# %%
album_df.head()
# Out:
#                  album_id                  name release_date  total_tracks  \
# 0  10FLjwfpbxLmW8c25Xyc2N      Die With A Smile   2024-08-16             1
# 1  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT   2024-05-17            10
# 2  5bBaoign62r1i7OV8w7mi9  Please Please Please   2024-06-06             2
# 3  5quMTd5zeI9yW5UDua8wS4              Espresso   2024-04-12             1
# 4  15XcLhiVMlSOipUddTNDnr                  MUSE   2024-07-19             7
#
#                                                  url
# 0  https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 1  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 2  https://open.spotify.com/album/5bBaoign62r1i7O...
# 3  https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 4  https://open.spotify.com/album/15XcLhiVMlSOipU...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, 0 to 48
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      40 non-null     object
#  1   name          40 non-null     object
#  2   release_date  40 non-null     datetime64[ns]
#  3   total_tracks  40 non-null     int64
#  4   url           40 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.9+ KB

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
